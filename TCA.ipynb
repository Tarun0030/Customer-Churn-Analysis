# %%
import pandas as pd
import numpy as py
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Customer churn.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# #replace blank value with 0 as tenure 0

# %%
df["TotalCharges"] = df["TotalCharges"].replace(" ", 0)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df["TotalCharges"] = df["TotalCharges"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df["customerID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
def conv(value):
    if value == 1:
        return "yes"
    else:
        return "no"
df["SeniorCitizen"] = df["SeniorCitizen"].apply(conv)

# %% [markdown]
# #converted 0 and 1 values of seniorcitizen to Yes/No for easier understanding

# %%
df.head(30)
# Out:
#     customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female            no     Yes         No       1           No
# 1   5575-GNVDE    Male            no      No         No      34          Yes
# 2   3668-QPYBK    Male            no      No         No       2          Yes
# 3   7795-CFOCW    Male            no      No         No      45           No
# 4   9237-HQITU  Female            no      No         No       2          Yes
# 5   9305-CDSKC  Female            no      No         No       8          Yes
# 6   1452-KIOVK    Male            no      No        Yes      22          Yes
# 7   6713-OKOMC  Female            no      No         No      10           No
# 8   7892-POOKP  Female            no     Yes         No      28          Yes
# 9   6388-TABGU    Male            no      No        Yes      62          Yes
# 10  9763-GRSKD    Male            no     Yes        Yes      13          Yes
# ...

# %%
sns.countplot(x = "Churn" , data = df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
ax = sns.countplot(x = "Churn" , data = df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '5174'), Text(0, 0, '1869')]

# %%
plt.figure(figsize = (4,4))
gp = df.groupby("Churn").agg({"Churn":"count"})
plt.pie(gp["Churn"], labels = gp.index, autopct = "%1.2f%%")
plt.title("Percentage of Churn Customers")
plt.show()

# %%
ax = sns.countplot(x = "gender", data = df, hue = "Churn")
ax.bar_label(ax.containers[0])
plt.title("Churn by Gender")
plt.show()

# %%
ax = sns.countplot(x = "SeniorCitizen", data = df, hue = "Churn" )
ax.bar_label(ax.containers[0])
plt.title("Churn by SeniorCitizen")
plt.show()

# %%
ax = sns.countplot(x = "SeniorCitizen", data = df,  )
ax.bar_label(ax.containers[0])
plt.title("Count of SeniorCitizen")
plt.show()

# %%
plt.figure(figsize = (9,4))
sns.histplot(x = "tenure", data = df, bins = 72, hue = "Churn")
#ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# #people who have used our service for a long time have stayed and people who have used our service 1 or 2 months churned

# %%
ax = sns.countplot(x = "Contract", data = df,hue = "Churn")
ax.bar_label(ax.containers[0])
plt.title("Count of Customer by Contract")
plt.show()

# %% [markdown]
# #people who have month to month contract are likely to churn then from those who have 1 or 2 years of contract

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
cols = [
    'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

plt.figure(figsize=(18, 15))
for i, col in enumerate(cols, 1):
    plt.subplot(3, 3, i)
    sns.countplot(data=df, x=col, hue='Churn', palette='pastel')
    plt.title(f'{col} vs Churn')
    plt.xticks(rotation=45)
    plt.tight_layout()

plt.suptitle("Churn Distribution Across Features", fontsize=20, y=1.02)
plt.show()

# %% [markdown]
# #This dataset contains telecom customer information related to services like Phone, Internet, and Streaming.
# Each feature is categorical (e.g., Yes/No) and helps in understanding customer behavior.
# It's mainly used to analyze patterns that influence customer churn.

# %%
plt.figure(figsize = (9,4))
ax = sns.countplot(x = "PaymentMethod", data = df,hue = "Churn")
ax.bar_label(ax.containers[0])
plt.title("Churned Customer by PaymentMethod")
plt.show()

# %% [markdown]
# #company is likely to churn when he is using electronic check as payment method
